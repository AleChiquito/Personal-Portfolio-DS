# %% [markdown]
# Problema: Dada una lista de enteros, devuelve el número que aparece más veces.
# Si hay empate en frecuencia, devuelve el número más pequeño.
#
# Input: [1, 3, 3, 2, 1, 3, 2, 2]
# Output: 2

# %%
list = [1,3,4,3,2,1,3,2,2,5]

# %%
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
