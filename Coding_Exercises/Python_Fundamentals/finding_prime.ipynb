# %%
def primo(num):
  for i in range(2,num):
    if num%i == 0:
      print("No es primo, tiene otro divisor: ",i)
      return False
  print("Si es primo")
  return True

# %%
num = int(input("Ingresa un número para saber si es primo: "))
print(primo(num))
# Out:
# Ingresa un número para saber si es primo: 111
# No es primo, tiene otro divisor:  3
# False
